# %%
# %fs ls /FileStore/tables/export.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/export.csv</td><td>export.csv</td><td>1467</td><td>1656667692000</td></tr></tbody></table></div>

# %%
df=spark.read.option('nullValue','null').csv('dbfs:/FileStore/tables/export.csv',header=True,inferSchema=True)

# %%
df.show()
# Out:
# +-----+------+---------+----+----------+----+----+------+
# |EMPNO| ENAME|      JOB| MGR|  HIREDATE| SAL|COMM|DEPTNO|
# +-----+------+---------+----+----------+----+----+------+
# | 7369| SMITH|    CLERK|7902|17-12-1980| 800|null|    20|
# | 7499| ALLEN| SALESMAN|7698|20-02-1981|1600| 300|    30|
# | 7521|  WARD| SALESMAN|7698|22-02-1981|1250| 500|    30|
# | 7566| JONES|  MANAGER|7839|04-02-1981|2975|null|    20|
# | 7654|MARTIN| SALESMAN|7698|21-09-1981|1250|1400|    30|
# | 7698|   SGR|  MANAGER|7839|05-01-1981|2850|null|    30|
# | 7782|  RAVI|  MANAGER|7839|06-09-1981|2450|null|    10|
# | 7788| SCOTT|  ANALYST|7566|19-04-1987|3000|null|    20|
# | 7839|  KING|PRESIDENT|null|01-11-1981|5000|null|    10|
# | 7844|  null| SALESMAN|7698|09-08-1981|1500|   0|    30|
# | 7876| ADAMS|    CLERK|7788|23-05-1987|1100|null|    20|
# | 7900| JAMES|    CLERK|7698|12-03-1981| 950|null|    30|
# | 7902|  FORD|     null|7566|12-03-1981|3000|null|    20|
# ...

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.columns
# Out:
# Out[7]: ['EMPNO', 'ENAME', 'JOB', 'MGR', 'HIREDATE', 'SAL', 'COMM', 'DEPTNO']

# %%
display(df.filter('mgr is null').count())
# Out:
# 2

# %%
from pyspark.sql.functions import count,col
display(df.select([count(col(i)) for i in df.columns]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(EMPNO)</th><th>count(ENAME)</th><th>count(JOB)</th><th>count(MGR)</th><th>count(HIREDATE)</th><th>count(SAL)</th><th>count(COMM)</th><th>count(DEPTNO)</th></tr></thead><tbody><tr><td>30</td><td>28</td><td>28</td><td>28</td><td>28</td><td>30</td><td>10</td><td>30</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import count,col,when

# %%
display(df.select([count(when(col(i).isNull(),i)) for i in df.columns]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(CASE WHEN (EMPNO IS NULL) THEN EMPNO END)</th><th>count(CASE WHEN (ENAME IS NULL) THEN ENAME END)</th><th>count(CASE WHEN (JOB IS NULL) THEN JOB END)</th><th>count(CASE WHEN (MGR IS NULL) THEN MGR END)</th><th>count(CASE WHEN (HIREDATE IS NULL) THEN HIREDATE END)</th><th>count(CASE WHEN (SAL IS NULL) THEN SAL END)</th><th>count(CASE WHEN (COMM IS NULL) THEN COMM END)</th><th>count(CASE WHEN (DEPTNO IS NULL) THEN DEPTNO END)</th></tr></thead><tbody><tr><td>0</td><td>2</td><td>2</td><td>2</td><td>2</td><td>0</td><td>20</td><td>0</td></tr></tbody></table></div>
