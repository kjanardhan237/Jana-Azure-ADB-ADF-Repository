# %%
from pyspark.sql import SparkSession
spark = SparkSession \
            .builder \
            .master('local[*]') \
            .config("spark.executor.memory", "5g") \
            .config("spark.sql.adaptive.enabled",True)\
            .config("spark.driver.memory", "5g") \
            .config("spark.memory.offHeap.enabled",True) \
            .config("spark.memory.offHeap.size","2g") \
            .config("spark.sql.repl.eagerEval.enabled", True)\
            .getOrCreate()

# %%
# display(dbuilts.fs.ls("/FileStore"))

# %%
# countries_df = spark.read.format("xml").option("rootTag", "countries").option("rowTag", "country").load("dbfs/FileStore/tables/countries.
# xml")
# countries_df.printSchema()
# print(countries_df.count())
# countries_df.cache()
# countries_df.show(10)

# %%
# employee_df=spark.read.csv("dbfs/FileStore/tables/countries.csv",inferSchema=True,header=True)

# %%
import urllib
import urllib.parse
ACCESS_KEY="AKIAYBX3MC5M44IGVXH3"
SECRET_KEY="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"
ENCODED_SECRET_KEY=urllib.parse.quote(SECRET_KEY,"")
AWS_BUCKETNAME="yuvasoft1"
MOUNT_NAME="projectdata"
dbutils.fs.mount("s3n://%s:%s@%s" % (ACCESS_KEY,ENCODED_SECRET_KEY,AWS_BUCKETNAME), "/mnt/%s" % MOUNT_NAME)
display(dbutils.fs.ls("/mnt/projectdata"))
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-1272687519940069> in <module>
#       6 AWS_BUCKETNAME="yuvasoft1"
#       7 MOUNT_NAME="projectdata"
# ----> 8 dbutils.fs.mount("s3n://%s:%s@%s" % (ACCESS_KEY,ENCODED_SECRET_KEY,AWS_BUCKETNAME), "/mnt/%s" % MOUNT_NAME)
#       9 display(dbutils.fs.ls("/mnt/projectdata"))
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     387                     exc.__context__ = None
#     388                     exc.__cause__ = None
# --> 389                     raise exc
#     390
#     391             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o410.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/projectdata; nested exception is:
# ...

# %%
def sub_unmount(str_path):
    if any(mount.mountPoint == str_path for mount in dbutils.fs.mount()):
        dbutils.fs.unmount(str_path)

# sub_unmount('/mnt/yavani1')

# %%
# display(dbuilts.fs.ls("/FileStore"))

# %%
display(dbutils.fs.ls("/mnt"))

# %%
# %sql
create database yavani_db;

# %%
# %sql
select * from yavani_db.employee_6_csv;

# %%
# %sql
select * from yavani_db.employee_6_csv where salary=100000;

# %%
# %sql
select * from yavani_db.employee_6_csv where salary<=100000;

# %%
# %sql
select * from yavani_db.employee_6_csv where salary >=50000;

# %%
# %sql
select * from yavani_db.employee_6_csv where salary!=100000;

# %%
df=spark.sql("select * from yavani_db.employee_6_csv")

# %%
df.show()

# %%
df=spark.sql("select * from yavani_db.employee_6_csv where salary=100000")

# %%
df.show()

# %%
df=spark.sql("select * from yavani_db.employee_6_csv where salary<=200000")

# %%
df.show()

# %%
df=spark.sql("select * from yavani_db.employee_6_csv where salary>=100000")

# %%
df.show()

# %%
 df=spark.sql("select * from yavani_db.employee_6_csv where salary in(100000,300000,40000)")

# %%
df.show()

# %%
from pyspark.sql.functions import count,col,desc
employee_df=spark.sql('select * from yavani_db.employee_6_csv')

# %%
employee_df.groupby("dept_id").agg(count('*')).alias("count").show()

# %%
employee_df.groupby("dept_id").agg({'salary':'max'}).show()

# %%
employee_df.groupby("dept_id").agg({'salary':'min'}).show()

# %%
employee_df.groupby('dept_id').count().sort(desc('count')).show()

# %%
employee_df.groupby('dept_id').count().sort('count').show()

# %%
employee_df.groupby('dept_id').sum('dept_id').show()

# %%
employee_df.printSchema()

# %%
employee_df=spark.read.csv("/FileStore/tables/employee-7.csv",header=True,inferSchema=True)
employee_df.show()

# %%
employee_df.printSchema()

# %%
employee_df=spark.sql("select * from yavani_db.employee_6_csv")
employee_df.show()

# %%
employee_df.printSchema()

# %%
employee_df.groupby("dept_id").sum("dept_id").show()

# %%
employee_df.groupby("dept_id").max("dept_id").show()

# %%
df=spark.read.csv()
