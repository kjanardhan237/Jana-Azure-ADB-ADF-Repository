# %%
#I have connected my S3 bucket from databricks.

#Using the following command :

import urllib

import urllib.parse

ACCESS_KEY = "AKIATIP7HFEQMYCNI64T"

SECRET_KEY = "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"

ENCODED_SECRET_KEY = urllib.parse.quote(SECRET_KEY, "") 
AWS_BUCKET_NAME = "jana-data"
MOUNT_NAME = "S3_Connection_details" 
dbutils.fs.mount("s3n://%s:%s@%s" % (ACCESS_KEY, ENCODED_SECRET_KEY,AWS_BUCKET_NAME), "/mnt/%s" % MOUNT_NAME)

#Now when I run the below command, I get the list of csv files present in the bucket.
# Out:
# Out[19]: True

# %%
display(dbutils.fs.ls("/mnt/S3_Connection_details"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/S3_Connection_details/username.csv</td><td>username.csv</td><td>176</td></tr></tbody></table></div>

# %%
import urllib

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
file_location="dbfs:/mnt/S3_Connection_details/username.csv"
file_type="csv"
infer_schema="true"
first_row_is_header="true"
delimiter=";"
df_read=spark.read.format(file_type) \
      .option("inferSchema",infer_schema) \
      .option("header",first_row_is_header) \
      .option("sep",delimiter) \
      .load(file_location)
display(df_read)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Username</th><th> Identifier</th><th>First name</th><th>Last name</th></tr></thead><tbody><tr><td>booker12</td><td>9012</td><td>Rachel</td><td>Booker</td></tr><tr><td>grey07</td><td>2070</td><td>Laura</td><td>Grey</td></tr><tr><td>johnson81</td><td>4081</td><td>Craig</td><td>Johnson</td></tr><tr><td>jenkins46</td><td>9346</td><td>Mary</td><td>Jenkins</td></tr><tr><td>smith79</td><td>5079</td><td>Jamie</td><td>Smith</td></tr></tbody></table></div>

# %%
# %sql
create database janardhan1;
use janardhan1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
df_read.write.format("parquet").saveAsTable(janardhan1+.+username.csv)
# Out:
#   File "<command-253239527782329>", line 1
#     df_read.write.format("parquet").saveAsTable(janardhan1+.+username.csv)
#                                                            ^
# SyntaxError: invalid syntax
