# %%
import urllib
import urllib.parse
ACCESS_KEY="AKIAZJJPJ36ZTLIUBHVB"
SECRET_KEY="anIFpDppzox+qpAo3Zf9U6fslgJjuczbTnk79C"
ENCODED_SECRET_KEY=urllib.parse.quote(SECRET_KEY,"")
AWS_BUCKETNAME="yavanibucket"
MOUNT_NAME="bhuvanaproject123"
dbutils.fs.mount("s3n://%s:%s@%s" % (ACCESS_KEY,ENCODED_SECRET_KEY,AWS_BUCKETNAME), "/mnt/%s" % MOUNT_NAME)
display(dbutils.fs.ls("/mnt/bhuvanaproject123/"))
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-932915332076726> in <module>
#       6 AWS_BUCKETNAME="yavanibucket"
#       7 MOUNT_NAME="bhuvanaproject123"
# ----> 8 dbutils.fs.mount("s3n://%s:%s@%s" % (ACCESS_KEY,ENCODED_SECRET_KEY,AWS_BUCKETNAME), "/mnt/%s" % MOUNT_NAME)
#       9 display(dbutils.fs.ls("/mnt/bhuvanaproject123/"))
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     385                     exc.__context__ = None
#     386                     exc.__cause__ = None
# --> 387                     raise exc
#     388
#     389             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o358.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/bhuvanaproject123; nested exception is:
# ...

# %%
display(dbutils.fs.ls("/mnt/bhuvanaproject123/"))
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-932915332076727> in <module>
# ----> 1 display(dbutils.fs.ls("/mnt/bhuvanaproject123/"))
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     385                     exc.__context__ = None
#     386                     exc.__cause__ = None
# --> 387                     raise exc
#     388
#     389             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling z:com.databricks.backend.daemon.dbutils.FSUtils.ls.
# ...

# %%
def sub_unmount(str_path):
    if any(mount.mountPoint == str_path for mount in dbutils.fs.mount()):
        dbutils.fs.unmount(str_path)

# %%
# %sql
create database yavani_db;

# %%
df=spark.read.formate("com.databricks.spark.xml").option("rowTag","").xml("")
