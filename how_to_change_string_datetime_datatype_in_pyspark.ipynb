# %%
dbutils.fs.put('/temp/jana/emp.csv',"""[EMPNO,ENAME,JOB,MGR,HIREDATE,SAL,COMM,DEPTNO
7369,SMITH,CLERK,7902,17-12-80,800,null,20
7499,ALLEN,SALESMAN,7698,20-02-81,1600,300,30
7521,WARD,SALESMAN,7698,22-02-81,1250,500,30
7566,JONES,MANAGER,7839,04-02-81,2975,null,20
7654,MARTIN,SALESMAN,7698,21-09-81,1250,1400,30
7698,SGR,MANAGER,7839,05-01-81,2850,null,30
7782,RAVI,MANAGER,7839,06-09-81,2450,null,10
7788,SCOTT,ANALYST,7566,19-04-87,3000,null,20
7839,KING,PRESIDENT,null,01-11-81,5000,null,10
7844,TURNER,SALESMAN,7698,09-08-81,1500,0,30
7876,ADAMS,CLERK,7788,23-05-87,1100,null,20
7900,JAMES,CLERK,7698,12-03-81,950,null,30
7902,FORD,ANALYST,7566,12-03-81,3000,null,20
7934,MILLER,CLERK,7782,01-03-82,1300,null,10
1234,SEKHAR,doctor,7777,31-12-99,667,78,80]""",True)
# Out:
# Wrote 721 bytes.
# Out[6]: True

# %%
# %fs ls /temp/jana/emp.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/temp/jana/emp.csv</td><td>emp.csv</td><td>721</td><td>1657689263000</td></tr></tbody></table></div>

# %%
df = spark.read.option("nullValue","null").csv("dbfs:/temp/jana/emp.csv",header=True,inferSchema=True)

# %%
df.show()
# Out:
# +------+------+---------+----+--------+----+----+------+
# |[EMPNO| ENAME|      JOB| MGR|HIREDATE| SAL|COMM|DEPTNO|
# +------+------+---------+----+--------+----+----+------+
# |  7369| SMITH|    CLERK|7902|17-12-80| 800|null|    20|
# |  7499| ALLEN| SALESMAN|7698|20-02-81|1600| 300|    30|
# |  7521|  WARD| SALESMAN|7698|22-02-81|1250| 500|    30|
# |  7566| JONES|  MANAGER|7839|04-02-81|2975|null|    20|
# |  7654|MARTIN| SALESMAN|7698|21-09-81|1250|1400|    30|
# |  7698|   SGR|  MANAGER|7839|05-01-81|2850|null|    30|
# |  7782|  RAVI|  MANAGER|7839|06-09-81|2450|null|    10|
# |  7788| SCOTT|  ANALYST|7566|19-04-87|3000|null|    20|
# |  7839|  KING|PRESIDENT|null|01-11-81|5000|null|    10|
# |  7844|TURNER| SALESMAN|7698|09-08-81|1500|   0|    30|
# |  7876| ADAMS|    CLERK|7788|23-05-87|1100|null|    20|
# |  7900| JAMES|    CLERK|7698|12-03-81| 950|null|    30|
# |  7902|  FORD|  ANALYST|7566|12-03-81|3000|null|    20|
# |  7934|MILLER|    CLERK|7782|01-03-82|1300|null|    10|
# |  1234|SEKHAR|   doctor|7777|31-12-99| 667|  78|   80]|
# +------+------+---------+----+--------+----+----+------+

# %%
from pyspark.sql.functions import to_date,col

# %%
display(df.withColumn('HIREDATE',to_date('HIREDATE','dd-mm-yy')))
# Default Spark Date Format yyyy-MM-dd
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>[EMPNO</th><th>ENAME</th><th>JOB</th><th>MGR</th><th>HIREDATE</th><th>SAL</th><th>COMM</th><th>DEPTNO</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902</td><td>1980-01-17</td><td>800</td><td>null</td><td>20</td></tr><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698</td><td>1981-01-20</td><td>1600</td><td>300</td><td>30</td></tr><tr><td>7521</td><td>WARD</td><td>SALESMAN</td><td>7698</td><td>1981-01-22</td><td>1250</td><td>500</td><td>30</td></tr><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839</td><td>1981-01-04</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7654</td><td>MARTIN</td><td>SALESMAN</td><td>7698</td><td>1981-01-21</td><td>1250</td><td>1400</td><td>30</td></tr><tr><td>7698</td><td>SGR</td><td>MANAGER</td><td>7839</td><td>1981-01-05</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>RAVI</td><td>MANAGER</td><td>7839</td><td>1981-01-06</td><td>2450</td><td>null</td><td>10</td></tr><tr><td>7788</td><td>SCOTT</td><td>ANALYST</td><td>7566</td><td>1987-01-19</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7839</td><td>KING</td><td>PRESIDENT</td><td>null</td><td>1981-01-01</td><td>5000</td><td>null</td><td>10</td></tr><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698</td><td>1981-01-09</td><td>1500</td><td>0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788</td><td>1987-01-23</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698</td><td>1981-01-12</td><td>950</td><td>null</td><td>30</td></tr><tr><td>7902</td><td>FORD</td><td>ANALYST</td><td>7566</td><td>1981-01-12</td><td>3000</td><td>null</td><td>20</td></tr><tr><td>7934</td><td>MILLER</td><td>CLERK</td><td>7782</td><td>1982-01-01</td><td>1300</td><td>null</td><td>10</td></tr><tr><td>1234</td><td>SEKHAR</td><td>doctor</td><td>7777</td><td>1999-01-31</td><td>667</td><td>78</td><td>80]</td></tr></tbody></table></div>

# %%
# %sql
select to_date('01-jan-85','dd-MMM-yy')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>to_date(01-jan-85, dd-MMM-yy)</th></tr></thead><tbody><tr><td>1985-01-01</td></tr></tbody></table></div>

# %%
# %sql
select to_date('01-jan-12','dd-MMM-yy')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>to_date(01-jan-12, dd-MMM-yy)</th></tr></thead><tbody><tr><td>2012-01-01</td></tr></tbody></table></div>
